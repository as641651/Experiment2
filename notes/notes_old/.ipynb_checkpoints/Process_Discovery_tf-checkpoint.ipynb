# %%
import pandas as pd

# %%
#df = pd.read_csv('../Matrix-Chain-4/logs/event_log-1.csv')
df = pd.read_csv('../Matrix-Chain-4/logs/event_log-10.csv')

# %%
df
# Out:
#    case:concept:name       concept:name    time:start      time:end  \
# 0               V5R0        matmul(A,B)  1.652893e+09  1.652893e+09
# 1               V5R0        matmul(C,D)  1.652893e+09  1.652893e+09
# 2               V5R0  matmul(T_AB,T_CD)  1.652893e+09  1.652893e+09
# 3               V4R0        matmul(C,D)  1.652893e+09  1.652893e+09
# 4               V4R0     matmul(B,T_CD)  1.652893e+09  1.652893e+09
# 5               V4R0    matmul(A,T_BCD)  1.652893e+09  1.652893e+09
# 6               V3R0        matmul(B,C)  1.652893e+09  1.652893e+09
# 7               V3R0     matmul(T_BC,D)  1.652893e+09  1.652893e+09
# 8               V3R0    matmul(A,T_BCD)  1.652893e+09  1.652893e+09
# 9               V1R1        matmul(A,B)  1.652893e+09  1.652893e+09
# 10              V1R1     matmul(T_AB,C)  1.652893e+09  1.652893e+09
# 11              V1R1    matmul(T_ABC,D)  1.652893e+09  1.652893e+09
# 12              V5R1        matmul(A,B)  1.652893e+09  1.652893e+09
# 13              V5R1        matmul(C,D)  1.652893e+09  1.652893e+09
# 14              V5R1  matmul(T_AB,T_CD)  1.652893e+09  1.652893e+09
# 15              V3R1        matmul(B,C)  1.652893e+09  1.652893e+09
# 16              V3R1     matmul(T_BC,D)  1.652893e+09  1.652893e+09
# 17              V3R1    matmul(A,T_BCD)  1.652893e+09  1.652893e+09
# 18              V6R1        matmul(C,D)  1.652893e+09  1.652893e+09
# 19              V6R1        matmul(A,B)  1.652893e+09  1.652893e+09
# 20              V6R1  matmul(T_AB,T_CD)  1.652893e+09  1.652893e+09
# 21              V1R0        matmul(A,B)  1.652893e+09  1.652893e+09
# 22              V1R0     matmul(T_AB,C)  1.652893e+09  1.652893e+09
# 23              V1R0    matmul(T_ABC,D)  1.652893e+09  1.652893e+09
# 24              V4R1        matmul(C,D)  1.652893e+09  1.652893e+09
# 25              V4R1     matmul(B,T_CD)  1.652893e+09  1.652893e+09
# 26              V4R1    matmul(A,T_BCD)  1.652893e+09  1.652893e+09
# 27              V2R1        matmul(B,C)  1.652893e+09  1.652893e+09
# 28              V2R1     matmul(A,T_BC)  1.652893e+09  1.652893e+09
# 29              V2R1    matmul(T_ABC,D)  1.652893e+09  1.652893e+09
# 30              V2R0        matmul(B,C)  1.652893e+09  1.652893e+09
# 31              V2R0     matmul(A,T_BC)  1.652893e+09  1.652893e+09
# 32              V2R0    matmul(T_ABC,D)  1.652893e+09  1.652893e+09
# 33              V6R0        matmul(C,D)  1.652893e+09  1.652893e+09
# 34              V6R0        matmul(A,B)  1.652893e+09  1.652893e+09
# 35              V6R0  matmul(T_AB,T_CD)  1.652893e+09  1.652893e+09
#
#                      case:dims  case:threads
# 0   [300, 4000, 30, 320, 3000]             4
# 1   [300, 4000, 30, 320, 3000]             4
# 2   [300, 4000, 30, 320, 3000]             4
# 3   [300, 4000, 30, 320, 3000]             4
# 4   [300, 4000, 30, 320, 3000]             4
# 5   [300, 4000, 30, 320, 3000]             4
# 6   [300, 4000, 30, 320, 3000]             4
# 7   [300, 4000, 30, 320, 3000]             4
# 8   [300, 4000, 30, 320, 3000]             4
# 9   [300, 4000, 30, 320, 3000]             4
# 10  [300, 4000, 30, 320, 3000]             4
# 11  [300, 4000, 30, 320, 3000]             4
# 12  [300, 4000, 30, 320, 3000]             4
# 13  [300, 4000, 30, 320, 3000]             4
# 14  [300, 4000, 30, 320, 3000]             4
# 15  [300, 4000, 30, 320, 3000]             4
# 16  [300, 4000, 30, 320, 3000]             4
# 17  [300, 4000, 30, 320, 3000]             4
# 18  [300, 4000, 30, 320, 3000]             4
# 19  [300, 4000, 30, 320, 3000]             4
# 20  [300, 4000, 30, 320, 3000]             4
# 21  [300, 4000, 30, 320, 3000]             4
# 22  [300, 4000, 30, 320, 3000]             4
# 23  [300, 4000, 30, 320, 3000]             4
# 24  [300, 4000, 30, 320, 3000]             4
# 25  [300, 4000, 30, 320, 3000]             4
# 26  [300, 4000, 30, 320, 3000]             4
# 27  [300, 4000, 30, 320, 3000]             4
# 28  [300, 4000, 30, 320, 3000]             4
# 29  [300, 4000, 30, 320, 3000]             4
# 30  [300, 4000, 30, 320, 3000]             4
# 31  [300, 4000, 30, 320, 3000]             4
# 32  [300, 4000, 30, 320, 3000]             4
# 33  [300, 4000, 30, 320, 3000]             4
# 34  [300, 4000, 30, 320, 3000]             4
# 35  [300, 4000, 30, 320, 3000]             4

# %% [markdown]
# ### Convert. CSV to XES

# %%
import pm4py
from pm4py.objects.log.util import dataframe_utils
from pm4py.objects.conversion.log import converter as log_converter

# %%
log_csv = dataframe_utils.convert_timestamp_columns_in_df(df)
log_csv = log_csv.sort_values('time:end')
event_log = log_converter.apply(log_csv)

# %%
pd.DataFrame(event_log[0])
# Out:
#         concept:name      time:end    time:start
# 0        matmul(A,B)  1.652893e+09  1.652893e+09
# 1        matmul(C,D)  1.652893e+09  1.652893e+09
# 2  matmul(T_AB,T_CD)  1.652893e+09  1.652893e+09

# %%
event_log[0].attributes
# Out:
# {'concept:name': 'V5R0', 'dims': '[300, 4000, 30, 320, 3000]', 'threads': 4}

# %% [markdown]
# ### Overview

# %%
from pm4py.statistics.traces.generic.log import case_statistics

# %%
variants_count = case_statistics.get_variant_statistics(event_log)

# %%
variants_count
# Out:
# [{'variant': 'matmul(C,D),matmul(B,T_CD),matmul(A,T_BCD)', 'count': 2},
#  {'variant': 'matmul(C,D),matmul(A,B),matmul(T_AB,T_CD)', 'count': 2},
#  {'variant': 'matmul(B,C),matmul(T_BC,D),matmul(A,T_BCD)', 'count': 2},
#  {'variant': 'matmul(B,C),matmul(A,T_BC),matmul(T_ABC,D)', 'count': 2},
#  {'variant': 'matmul(A,B),matmul(T_AB,C),matmul(T_ABC,D)', 'count': 2},
#  {'variant': 'matmul(A,B),matmul(C,D),matmul(T_AB,T_CD)', 'count': 2}]

# %% [markdown]
# ### Process discovery

# %% [markdown]
# #### Alpha miner

# %%
from pm4py.algo.discovery.alpha import algorithm as alpha_miner
from pm4py.visualization.petri_net import visualizer as pn_visualizer

# %%
net, initial_marking, final_marking = alpha_miner.apply(event_log)

# %%
gviz = pn_visualizer.apply(net, initial_marking, final_marking)

# %%
pn_visualizer.view(gviz)

# %%
dfg, sa, ea = pm4py.discover_directly_follows_graph(event_log)

# %%
dfg
# Out:
# Counter({('matmul(A,B)', 'matmul(C,D)'): 2,
#          ('matmul(C,D)', 'matmul(T_AB,T_CD)'): 2,
#          ('matmul(C,D)', 'matmul(B,T_CD)'): 2,
#          ('matmul(B,T_CD)', 'matmul(A,T_BCD)'): 2,
#          ('matmul(B,C)', 'matmul(T_BC,D)'): 2,
#          ('matmul(T_BC,D)', 'matmul(A,T_BCD)'): 2,
#          ('matmul(A,B)', 'matmul(T_AB,C)'): 2,
#          ('matmul(T_AB,C)', 'matmul(T_ABC,D)'): 2,
#          ('matmul(C,D)', 'matmul(A,B)'): 2,
#          ('matmul(A,B)', 'matmul(T_AB,T_CD)'): 2,
#          ('matmul(B,C)', 'matmul(A,T_BC)'): 2,
#          ('matmul(A,T_BC)', 'matmul(T_ABC,D)'): 2})

# %% [markdown]
# ### Heuristic Miner

# %%
from pm4py.algo.discovery.heuristics import algorithm as heuristics_miner
from pm4py.visualization.heuristics_net import visualizer as hn_visualizer

# %%
net, im, fm = heuristics_miner.apply(event_log, parameters={heuristics_miner.Variants.CLASSIC.value.Parameters.DEPENDENCY_THRESH: 0.0})

gviz = pn_visualizer.apply(net,im,fm)
pn_visualizer.view(gviz)

# %% [markdown]
# ### Inductive Miner

# %%
from pm4py.algo.discovery.inductive import algorithm as inductive_miner
from pm4py.visualization.petri_net import visualizer as pn_visualizer

# %%
net, initial_marking, final_marking = inductive_miner.apply(event_log)

# %%
gviz = pn_visualizer.apply(net, initial_marking, final_marking)

# %%
pn_visualizer.view(gviz)
