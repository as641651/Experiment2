# %%
import sys
sys.path.append("../utils/")

# %%
from runner import Runner
from run_competing import RunCompeting
from rank_variants import RankVariants
from discover_pn import DiscoverPN
import pm4py
import pandas as pd

# %%
exp_name = "GLS"
script_path = "../GLS/variants-linnea/generate-variants-linnea.py"
args = ["1000","10"]
runner = Runner(exp_name, script_path , args)

# %%
run_competing = RunCompeting(runner)
run_competing.generate_run(bRun=True,bGenerate=True)
#run_competing.generate_run(bRun=False,bGenerate=False)
#
ct = run_competing.set_best_flop_duration_as_competing()
# Out:
# New solution:.............3.54e+08
# New solution:.............3.44e+08
# Nodes:.........................402
# Nodes:.........................736
# Nodes:........................1016
# Nodes:........................1301
# Nodes:........................1662
# Time limit reached.
# ----------------------------------
# Number of nodes:              1662
# Solution nodes:                 16
# Data:                     5.11e+05
# Best solution:            3.44e+08
# Intensity:                     674
# Number of algorithms:          100
# Generated Variants.
# Running Experiments
# Experiments completed

# %%
ct
# Out:
#    case:concept:name  case:timestamp:start  case:timestamp:end  case:duration  \
# 4        algorithm12          1.655491e+09        1.655491e+09       0.005836
# 8        algorithm26          1.655491e+09        1.655491e+09       0.005403
# 14       algorithm22          1.655491e+09        1.655491e+09       0.005963
# 17       algorithm16          1.655491e+09        1.655491e+09       0.005394
# 23       algorithm23          1.655491e+09        1.655491e+09       0.006212
# 26       algorithm17          1.655491e+09        1.655491e+09       0.006243
# 31       algorithm13          1.655491e+09        1.655491e+09       0.005936
# 37       algorithm18          1.655491e+09        1.655491e+09       0.005698
# 39        algorithm1          1.655491e+09        1.655491e+09       0.005754
# 44        algorithm5          1.655491e+09        1.655491e+09       0.006512
# 49        algorithm4          1.655491e+09        1.655491e+09       0.005398
# 51       algorithm19          1.655491e+09        1.655491e+09       0.005664
# 53        algorithm0          1.655491e+09        1.655491e+09       0.005797
# 56        algorithm7          1.655491e+09        1.655491e+09       0.005692
# 57        algorithm3          1.655491e+09        1.655491e+09       0.009383
# 58        algorithm2          1.655491e+09        1.655491e+09       0.005718
# 61        algorithm6          1.655491e+09        1.655491e+09       0.006068
# 67       algorithm20          1.655491e+09        1.655491e+09       0.005316
# 69       algorithm14          1.655491e+09        1.655491e+09       0.011397
# 76       algorithm10          1.655491e+09        1.655491e+09       0.006583
# 77       algorithm24          1.655491e+09        1.655491e+09       0.005587
# 80        algorithm9          1.655491e+09        1.655491e+09       0.005536
# 86       algorithm11          1.655491e+09        1.655491e+09       0.004976
# 87       algorithm25          1.655491e+09        1.655491e+09       0.005445
# 90        algorithm8          1.655491e+09        1.655491e+09       0.004924
# 96       algorithm21          1.655491e+09        1.655491e+09       0.005271
# 98       algorithm15          1.655491e+09        1.655491e+09       0.008885
# 89       algorithm87          1.655491e+09        1.655491e+09       0.004912
#
#      case:flops  case:num_kernels  case:rel-flops  case:rel-duration
# 4   344000000.0                 8             0.0           0.000924
# 8   344000000.0                 8             0.0           0.000491
# 14  344000000.0                 8             0.0           0.001051
# 17  344000000.0                 8             0.0           0.000482
# 23  344000000.0                 8             0.0           0.001300
# 26  344000000.0                 8             0.0           0.001331
# 31  344000000.0                 8             0.0           0.001024
# 37  344000000.0                 8             0.0           0.000786
# 39  344000000.0                 8             0.0           0.000842
# 44  344000000.0                 8             0.0           0.001600
# 49  344000000.0                 8             0.0           0.000486
# 51  344000000.0                 8             0.0           0.000752
# 53  344000000.0                 8             0.0           0.000885
# 56  344000000.0                 8             0.0           0.000780
# 57  344000000.0                 8             0.0           0.004471
# 58  344000000.0                 8             0.0           0.000806
# 61  344000000.0                 8             0.0           0.001156
# 67  344000000.0                 8             0.0           0.000404
# 69  344000000.0                 8             0.0           0.006485
# 76  344000000.0                 8             0.0           0.001671
# 77  344000000.0                 8             0.0           0.000675
# 80  344000000.0                 8             0.0           0.000624
# 86  344000000.0                 8             0.0           0.000064
# 87  344000000.0                 8             0.0           0.000533
# 90  344000000.0                 8             0.0           0.000012
# 96  344000000.0                 8             0.0           0.000359
# 98  344000000.0                 8             0.0           0.003973
# 89  345000000.0                 8       1000000.0           0.000000

# %%
run_competing.measure_competing_variants(reps=10)
run_competing.prepare_event_data()
measurements = run_competing.duration_competing
measurements.head()
# Out:
# Running Experiments
# Experiments completed
#   case:concept:name  case:timestamp:start  case:timestamp:end  case:duration
# 0     algorithm18_8          1.655491e+09        1.655491e+09       0.006652
# 1     algorithm24_4          1.655491e+09        1.655491e+09       0.005835
# 2      algorithm5_4          1.655491e+09        1.655491e+09       0.005851
# 3     algorithm24_0          1.655491e+09        1.655491e+09       0.009238
# 4     algorithm87_4          1.655491e+09        1.655491e+09       0.005403

# %%
ct
# Out:
#    case:concept:name  case:timestamp:start  case:timestamp:end  case:duration  \
# 4        algorithm12          1.655491e+09        1.655491e+09       0.005836
# 8        algorithm26          1.655491e+09        1.655491e+09       0.005403
# 14       algorithm22          1.655491e+09        1.655491e+09       0.005963
# 17       algorithm16          1.655491e+09        1.655491e+09       0.005394
# 23       algorithm23          1.655491e+09        1.655491e+09       0.006212
# 26       algorithm17          1.655491e+09        1.655491e+09       0.006243
# 31       algorithm13          1.655491e+09        1.655491e+09       0.005936
# 37       algorithm18          1.655491e+09        1.655491e+09       0.005698
# 39        algorithm1          1.655491e+09        1.655491e+09       0.005754
# 44        algorithm5          1.655491e+09        1.655491e+09       0.006512
# 49        algorithm4          1.655491e+09        1.655491e+09       0.005398
# 51       algorithm19          1.655491e+09        1.655491e+09       0.005664
# 53        algorithm0          1.655491e+09        1.655491e+09       0.005797
# 56        algorithm7          1.655491e+09        1.655491e+09       0.005692
# 57        algorithm3          1.655491e+09        1.655491e+09       0.009383
# 58        algorithm2          1.655491e+09        1.655491e+09       0.005718
# 61        algorithm6          1.655491e+09        1.655491e+09       0.006068
# 67       algorithm20          1.655491e+09        1.655491e+09       0.005316
# 69       algorithm14          1.655491e+09        1.655491e+09       0.011397
# 76       algorithm10          1.655491e+09        1.655491e+09       0.006583
# 77       algorithm24          1.655491e+09        1.655491e+09       0.005587
# 80        algorithm9          1.655491e+09        1.655491e+09       0.005536
# 86       algorithm11          1.655491e+09        1.655491e+09       0.004976
# 87       algorithm25          1.655491e+09        1.655491e+09       0.005445
# 90        algorithm8          1.655491e+09        1.655491e+09       0.004924
# 96       algorithm21          1.655491e+09        1.655491e+09       0.005271
# 98       algorithm15          1.655491e+09        1.655491e+09       0.008885
# 89       algorithm87          1.655491e+09        1.655491e+09       0.004912
#
#      case:flops  case:num_kernels  case:rel-flops  case:rel-duration
# 4   344000000.0                 8             0.0           0.000924
# 8   344000000.0                 8             0.0           0.000491
# 14  344000000.0                 8             0.0           0.001051
# 17  344000000.0                 8             0.0           0.000482
# 23  344000000.0                 8             0.0           0.001300
# 26  344000000.0                 8             0.0           0.001331
# 31  344000000.0                 8             0.0           0.001024
# 37  344000000.0                 8             0.0           0.000786
# 39  344000000.0                 8             0.0           0.000842
# 44  344000000.0                 8             0.0           0.001600
# 49  344000000.0                 8             0.0           0.000486
# 51  344000000.0                 8             0.0           0.000752
# 53  344000000.0                 8             0.0           0.000885
# 56  344000000.0                 8             0.0           0.000780
# 57  344000000.0                 8             0.0           0.004471
# 58  344000000.0                 8             0.0           0.000806
# 61  344000000.0                 8             0.0           0.001156
# 67  344000000.0                 8             0.0           0.000404
# 69  344000000.0                 8             0.0           0.006485
# 76  344000000.0                 8             0.0           0.001671
# 77  344000000.0                 8             0.0           0.000675
# 80  344000000.0                 8             0.0           0.000624
# 86  344000000.0                 8             0.0           0.000064
# 87  344000000.0                 8             0.0           0.000533
# 90  344000000.0                 8             0.0           0.000012
# 96  344000000.0                 8             0.0           0.000359
# 98  344000000.0                 8             0.0           0.003973
# 89  345000000.0                 8       1000000.0           0.000000

# %% [markdown]
# ## Initial Hypothesis: Sort algorithms by single-run execution time

# %%
alg_list = list(ct.sort_values(by=['case:duration'])['case:concept:name'])
alg_list
# Out:
# ['algorithm87',
#  'algorithm8',
#  'algorithm11',
#  'algorithm21',
#  'algorithm20',
#  'algorithm16',
#  'algorithm4',
#  'algorithm26',
#  'algorithm25',
#  'algorithm9',
#  'algorithm24',
#  'algorithm19',
#  'algorithm7',
#  'algorithm18',
#  'algorithm2',
#  'algorithm1',
#  'algorithm0',
#  'algorithm12',
#  'algorithm13',
#  'algorithm22',
#  'algorithm6',
#  'algorithm23',
#  'algorithm17',
#  'algorithm5',
#  'algorithm10',
#  'algorithm15',
#  'algorithm3',
#  'algorithm14']

# %%
rank_variants = RankVariants(measurements,alg_list)
ranks = rank_variants.sortAlgs(75,25)
all_ranks, mean_ranks = rank_variants.calculate_mean_rank()

# %%
pd.DataFrame(rank_variants.comparision_matrix)
# Out:
#              algorithm87  algorithm8  algorithm11  algorithm21  algorithm20  \
# algorithm87           -1           2           -1           -1           -1
# algorithm8             0          -1            1           -1           -1
# algorithm11           -1           1           -1            1            1
# algorithm21           -1          -1            1           -1            0
# algorithm20           -1          -1            1            2           -1
# algorithm16           -1          -1           -1            1           -1
# algorithm4             2           2            2            2            2
# algorithm26           -1          -1           -1           -1           -1
# algorithm25           -1          -1           -1           -1           -1
# algorithm9            -1          -1           -1           -1           -1
# algorithm24           -1          -1           -1           -1           -1
# algorithm19           -1          -1           -1           -1           -1
# algorithm7            -1          -1           -1           -1           -1
# algorithm18           -1          -1           -1           -1           -1
# algorithm2            -1          -1           -1           -1           -1
# algorithm1            -1          -1           -1           -1           -1
# algorithm0            -1          -1           -1           -1           -1
# algorithm12           -1          -1           -1           -1           -1
# algorithm13           -1          -1           -1           -1           -1
# algorithm22           -1          -1           -1           -1           -1
# algorithm6            -1          -1           -1           -1           -1
# algorithm23           -1          -1           -1           -1           -1
# algorithm17           -1          -1           -1           -1           -1
# algorithm5            -1          -1           -1           -1           -1
# algorithm10           -1          -1           -1           -1           -1
# algorithm15           -1          -1           -1           -1           -1
# algorithm3            -1          -1           -1           -1           -1
# algorithm14           -1          -1           -1           -1           -1
#
#              algorithm16  algorithm4  algorithm26  algorithm25  algorithm9  \
# algorithm87           -1           0           -1           -1          -1
# algorithm8            -1           0           -1           -1          -1
# algorithm11           -1           0           -1           -1          -1
# algorithm21            1           0           -1           -1          -1
# algorithm20           -1           0           -1           -1          -1
# algorithm16           -1           0            1           -1          -1
# algorithm4             2          -1           -1           -1          -1
# algorithm26            1          -1           -1            1          -1
# algorithm25           -1          -1            1           -1           1
# algorithm9            -1          -1           -1            1          -1
# algorithm24           -1          -1           -1           -1           1
# algorithm19           -1          -1           -1           -1          -1
# algorithm7            -1          -1            1            2           2
# algorithm18           -1          -1           -1           -1          -1
# algorithm2            -1          -1           -1           -1          -1
# algorithm1            -1          -1           -1            2           2
# algorithm0            -1          -1           -1           -1          -1
# algorithm12           -1          -1           -1           -1          -1
# algorithm13           -1          -1           -1           -1          -1
# algorithm22           -1          -1           -1           -1          -1
# algorithm6            -1          -1           -1           -1          -1
# algorithm23           -1          -1           -1           -1          -1
# algorithm17           -1          -1           -1           -1          -1
# algorithm5            -1          -1           -1           -1          -1
# algorithm10           -1          -1           -1           -1          -1
# algorithm15           -1          -1           -1           -1          -1
# algorithm3            -1          -1           -1           -1          -1
# algorithm14           -1          -1           -1           -1          -1
#
#              ...  algorithm13  algorithm22  algorithm6  algorithm23  \
# algorithm87  ...           -1           -1          -1           -1
# algorithm8   ...           -1           -1          -1           -1
# algorithm11  ...           -1           -1          -1           -1
# algorithm21  ...           -1           -1          -1           -1
# algorithm20  ...           -1           -1          -1           -1
# algorithm16  ...           -1           -1          -1           -1
# algorithm4   ...           -1           -1          -1           -1
# algorithm26  ...           -1           -1          -1           -1
# algorithm25  ...           -1           -1          -1           -1
# algorithm9   ...           -1           -1          -1           -1
# algorithm24  ...           -1           -1          -1           -1
# algorithm19  ...           -1           -1          -1           -1
# algorithm7   ...           -1           -1          -1           -1
# algorithm18  ...           -1           -1          -1           -1
# algorithm2   ...           -1           -1          -1           -1
# algorithm1   ...           -1           -1          -1           -1
# algorithm0   ...           -1           -1          -1           -1
# algorithm12  ...            1           -1          -1           -1
# algorithm13  ...           -1            1          -1            1
# algorithm22  ...            1           -1           1            0
# algorithm6   ...           -1            1          -1            0
# algorithm23  ...            1            2           2           -1
# algorithm17  ...           -1            2           2            1
# algorithm5   ...           -1           -1           1           -1
# algorithm10  ...           -1           -1          -1           -1
# algorithm15  ...           -1           -1          -1           -1
# algorithm3   ...           -1           -1          -1           -1
# algorithm14  ...           -1           -1          -1           -1
#
#              algorithm17  algorithm5  algorithm10  algorithm15  algorithm3  \
# algorithm87           -1          -1           -1           -1          -1
# algorithm8            -1          -1           -1           -1          -1
# algorithm11           -1          -1           -1           -1          -1
# algorithm21           -1          -1           -1           -1          -1
# algorithm20           -1          -1           -1           -1          -1
# algorithm16           -1          -1           -1           -1          -1
# algorithm4            -1          -1           -1           -1          -1
# algorithm26           -1          -1           -1           -1          -1
# algorithm25           -1          -1           -1           -1          -1
# algorithm9            -1          -1           -1           -1          -1
# algorithm24           -1          -1           -1           -1          -1
# algorithm19           -1          -1           -1           -1          -1
# algorithm7            -1          -1           -1           -1          -1
# algorithm18           -1          -1           -1           -1          -1
# algorithm2            -1          -1           -1           -1          -1
# algorithm1            -1          -1           -1           -1          -1
# algorithm0            -1          -1           -1           -1          -1
# algorithm12           -1          -1           -1           -1          -1
# algorithm13           -1          -1           -1           -1          -1
# algorithm22            0          -1           -1           -1          -1
# algorithm6             0           1           -1           -1          -1
# algorithm23            1          -1           -1           -1          -1
# algorithm17           -1          -1           -1           -1          -1
# algorithm5            -1          -1            2            1          -1
# algorithm10           -1           0           -1            0           1
# algorithm15           -1           1            2           -1          -1
# algorithm3            -1          -1            1           -1          -1
# algorithm14           -1          -1           -1           -1           1
#
#              algorithm14
# algorithm87           -1
# algorithm8            -1
# algorithm11           -1
# algorithm21           -1
# algorithm20           -1
# algorithm16           -1
# algorithm4            -1
# algorithm26           -1
# algorithm25           -1
# algorithm9            -1
# algorithm24           -1
# algorithm19           -1
# algorithm7            -1
# algorithm18           -1
# algorithm2            -1
# algorithm1            -1
# algorithm0            -1
# algorithm12           -1
# algorithm13           -1
# algorithm22           -1
# algorithm6            -1
# algorithm23           -1
# algorithm17           -1
# algorithm5            -1
# algorithm10           -1
# algorithm15           -1
# algorithm3             1
# algorithm14           -1
#
# [28 rows x 28 columns]

# %%
ranks
# Out:
#    case:concept:name  case:rank
# 0        algorithm87          0
# 1         algorithm8          0
# 2        algorithm11          0
# 3        algorithm21          0
# 4        algorithm20          0
# 5         algorithm4          0
# 6        algorithm16          1
# 7        algorithm26          1
# 8        algorithm25          1
# 9         algorithm9          1
# 10       algorithm24          1
# 11       algorithm19          1
# 12        algorithm7          1
# 13       algorithm18          1
# 14        algorithm2          1
# 15        algorithm1          1
# 16        algorithm0          1
# 17       algorithm12          1
# 18       algorithm13          1
# 19       algorithm22          1
# 20        algorithm6          1
# 21       algorithm23          1
# 22       algorithm17          1
# 23        algorithm5          1
# 24       algorithm10          1
# 25       algorithm15          1
# 26        algorithm3          1
# 27       algorithm14          1

# %%
all_ranks
# Out:
#                    case:rank  case:rank  case:rank  case:rank  case:rank  \
# case:concept:name
# algorithm87                0          0          0          0          0
# algorithm8                 0          0          0          0          0
# algorithm11                0          0          0          0          0
# algorithm21                0          0          0          0          0
# algorithm20                0          0          0          0          0
# algorithm16                0          0          0          0          1
# algorithm4                 0          0          0          0          0
# algorithm26                0          0          0          0          1
# algorithm25                0          0          0          0          1
# algorithm9                 0          0          0          0          1
# algorithm24                0          0          0          0          1
# algorithm19                0          0          0          0          1
# algorithm7                 0          0          0          0          1
# algorithm18                0          0          0          0          1
# algorithm2                 0          0          0          0          1
# algorithm1                 0          0          0          0          1
# algorithm0                 0          0          0          0          1
# algorithm12                0          0          0          0          1
# algorithm13                0          0          0          0          1
# algorithm22                0          0          0          0          1
# algorithm6                 0          0          0          0          1
# algorithm23                0          0          0          0          1
# algorithm17                0          0          0          0          1
# algorithm5                 0          0          0          0          1
# algorithm10                0          0          0          0          1
# algorithm15                0          0          0          0          1
# algorithm3                 0          0          0          0          1
# algorithm14                0          0          0          0          1
#
#                    case:rank  case:rank
# case:concept:name
# algorithm87                0          1
# algorithm8                 1          2
# algorithm11                1          2
# algorithm21                1          3
# algorithm20                1          2
# algorithm16                1          3
# algorithm4                 0          0
# algorithm26                1          3
# algorithm25                1          3
# algorithm9                 1          3
# algorithm24                1          3
# algorithm19                1          3
# algorithm7                 1          3
# algorithm18                1          3
# algorithm2                 2          3
# algorithm1                 1          3
# algorithm0                 2          3
# algorithm12                2          3
# algorithm13                2          3
# algorithm22                2          4
# algorithm6                 2          4
# algorithm23                2          3
# algorithm17                2          3
# algorithm5                 2          4
# algorithm10                2          4
# algorithm15                2          4
# algorithm3                 2          4
# algorithm14                2          4

# %%
mean_ranks
# Out:
#    case:concept:name  case:mean-rank
# 6         algorithm4        0.000000
# 0        algorithm87        0.142857
# 1         algorithm8        0.428571
# 2        algorithm11        0.428571
# 4        algorithm20        0.428571
# 3        algorithm21        0.571429
# 15        algorithm1        0.714286
# 12        algorithm7        0.714286
# 11       algorithm19        0.714286
# 10       algorithm24        0.714286
# 13       algorithm18        0.714286
# 8        algorithm25        0.714286
# 7        algorithm26        0.714286
# 5        algorithm16        0.714286
# 9         algorithm9        0.714286
# 14        algorithm2        0.857143
# 16        algorithm0        0.857143
# 17       algorithm12        0.857143
# 18       algorithm13        0.857143
# 21       algorithm23        0.857143
# 22       algorithm17        0.857143
# 25       algorithm15        1.000000
# 24       algorithm10        1.000000
# 19       algorithm22        1.000000
# 20        algorithm6        1.000000
# 26        algorithm3        1.000000
# 23        algorithm5        1.000000
# 27       algorithm14        1.000000

# %%
rank_variants.show_measurements_boxplots(outliers=False)

# %% [markdown]
# ## Insights

# %%
et = run_competing.event_table_competing
et
# Out:
#      case:concept:name                     concept:name  concept:flops  \
# 0        algorithm18_8            LAPACK.potrf_3.33e+08    333000000.0
# 1        algorithm18_8                       trsm_1e+07     10000000.0
# 2        algorithm18_8                       syrk_1e+05       100000.0
# 3        algorithm18_8  ml4, ml3 = LAPACK.syev_3.43e+03         3430.0
# 4        algorithm18_8                       trsv_1e+06      1000000.0
# ...                ...                              ...            ...
# 2235     algorithm24_6                       trsv_1e+06      1000000.0
# 2236     algorithm24_6                       gemv_2e+04        20000.0
# 2237     algorithm24_6  ml5, ml3 = LAPACK.syev_3.43e+03         3430.0
# 2238     algorithm24_6                         gemv_200          200.0
# 2239     algorithm24_6                          gemv_10           10.0
#
#              concept:operation                            concept:kernel  \
# 0                (L7 L7^T) = M                   LAPACK.potrf!('L', ml1)
# 1            tmp12 = (L7^-1 X)  trsm!('L', 'L', 'N', 'N', 1.0, ml1, ml0)
# 2      tmp14 = (tmp12^T tmp12)       syrk!('L', 'T', 1.0, ml0, 0.0, ml3)
# 3      (Z18 W19 Z18^T) = tmp14    ml4, ml3 = LAPACK.syev!('V', 'L', ml3)
# 4            tmp68 = (L7^-1 y)            trsv!('L', 'N', 'N', ml1, ml2)
# ...                        ...                                       ...
# 2235         tmp68 = (L7^-1 y)            trsv!('L', 'N', 'N', ml1, ml2)
# 2236   tmp21 = (tmp12^T tmp68)       gemv!('T', 1.0, ml0, ml2, 0.0, ml4)
# 2237   (Z18 W19 Z18^T) = tmp14    ml5, ml3 = LAPACK.syev!('V', 'L', ml3)
# 2238    tmp268 = (Z18^T tmp21)       gemv!('T', 1.0, ml3, ml4, 0.0, ml6)
# 2239  tmp269 = (W19^-1 tmp268)       gemv!('N', 1.0, ml3, ml6, 0.0, ml7)
#
#       timestamp:start  timestamp:end
# 0        1.655491e+09   1.655491e+09
# 1        1.655491e+09   1.655491e+09
# 2        1.655491e+09   1.655491e+09
# 3        1.655491e+09   1.655491e+09
# 4        1.655491e+09   1.655491e+09
# ...               ...            ...
# 2235     1.655491e+09   1.655491e+09
# 2236     1.655491e+09   1.655491e+09
# 2237     1.655491e+09   1.655491e+09
# 2238     1.655491e+09   1.655491e+09
# 2239     1.655491e+09   1.655491e+09
#
# [2240 rows x 7 columns]

# %%
pn = DiscoverPN(et)
for trace in pn.event_log:
    alg = trace.attributes['concept:name'].split('_')[0]
    alg_rank = ranks[ranks['case:concept:name'] == alg]['case:rank'].values[0]
    alg_mean_rank = mean_ranks[mean_ranks['case:concept:name'] == alg]['case:mean-rank'].values[0]
    trace.attributes['case:algorithm'] = alg
    trace.attributes['case:rank'] = alg_rank
    trace.attributes['case:mean-rank'] = alg_mean_rank

# %%
#for trace in pn.event_log:
#    print(trace.attributes)

# %%
def filtered_log_by_rank(log,rank):
    filtered_log = pm4py.filter_log(lambda x: x.attributes['case:rank'] == rank, log)
    return filtered_log

def filtered_log_by_alg_list(log,alg_list):
    filtered_log = pm4py.filter_log(lambda x: x.attributes['case:algorithm'] in alg_list, log)
    return filtered_log

# %% [markdown]
# ### Algorithm 1

# %%
filtered_log_by_alg = filtered_log_by_alg_list(pn.event_log, ['algorithm1'])

# for trace in filtered_log_by_alg:
#     print(trace.attributes)

net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log_by_alg)
pn.visualize_pn(net, im, fm)

# %% [markdown]
# ### Algorithm 0

# %%
filtered_log_by_alg = filtered_log_by_alg_list(pn.event_log, ['algorithm0'])
net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log_by_alg)
pn.visualize_pn(net, im, fm)

# %%
for trace in filtered_log_by_alg:
    for event in trace:
        if 'tmp23' in event['concept:operation']:
            print(event['concept:operation'], event['timestamp:start'])
    print("\n")
    #print(trace.__dict__['_list'][0]['concept:operation'], trace.__dict__['_list'][0]['timestamp:start'])
# Out:
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:49.275662+00:00
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:49.275662+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:49.445737+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:49.445737+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:49.695054+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:49.695055+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:49.869752+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:49.869753+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:49.916777+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:49.916777+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:50.030728+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:50.030729+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:50.040268+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:50.040268+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:50.443100+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:50.443101+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:50.479685+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:50.479686+00:00
#
#
# tmp23 = (L15^-1 tmp21) 2022-06-17 20:39:50.778882+00:00
# tmp24 = (L15^-T tmp23) 2022-06-17 20:39:50.778883+00:00

# %% [markdown]
# ## Work flow: Rank 0 algorithms

# %% [markdown]
# ### Knernels Used

# %%
filtered_log=filtered_log_by_rank(pn.event_log,0)
net, im, fm = pn.inductive_miner(filtered_log=filtered_log)
pn.visualize_pn(net, im, fm)

# %%
net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log)
pn.visualize_pn(net, im, fm)
