# %%
import sys
sys.path.append("../utils/")

# %%
from runner import Runner
from run_competing import RunCompeting
from rank_variants import RankVariants
from discover_pn import DiscoverPN
import pm4py
import pandas as pd

# %%
exp_name = "GLS"
script_path = "../GLS/variants-linnea/generate-variants-linnea.py"
args = ["1000","10"]
runner = Runner(exp_name, script_path , args)

# %%
run_competing = RunCompeting(runner)
run_competing.generate_run(bRun=True,bGenerate=True)
#run_competing.generate_run(bRun=False,bGenerate=False)

ct = run_competing.set_best_flop_duration_as_competing()
# Out:
# New solution:.............3.54e+08
# New solution:.............3.44e+08
# Nodes:.........................393
# Nodes:.........................725
# Nodes:.........................998
# Nodes:........................1287
# Nodes:........................1645
# Time limit reached.
# ----------------------------------
# Number of nodes:              1645
# Solution nodes:                 16
# Data:                     5.11e+05
# Best solution:            3.44e+08
# Intensity:                     674
# Number of algorithms:          100
# Generated Variants.
# Running Experiments
# Experiments completed

# %%
ct
# Out:
#    case:concept:name  case:timestamp:start  case:timestamp:end  case:duration  \
# 4        algorithm12          1.655483e+09        1.655483e+09       0.008335
# 8        algorithm26          1.655483e+09        1.655483e+09       0.006196
# 14       algorithm22          1.655483e+09        1.655483e+09       0.005923
# 17       algorithm16          1.655483e+09        1.655483e+09       0.005245
# 23       algorithm23          1.655483e+09        1.655483e+09       0.005202
# 26       algorithm17          1.655483e+09        1.655483e+09       0.005657
# 31       algorithm13          1.655483e+09        1.655483e+09       0.005322
# 37       algorithm18          1.655483e+09        1.655483e+09       0.004730
# 39        algorithm1          1.655483e+09        1.655483e+09       0.005323
# 44        algorithm5          1.655483e+09        1.655483e+09       0.005722
# 49        algorithm4          1.655483e+09        1.655483e+09       0.005721
# 51       algorithm19          1.655483e+09        1.655483e+09       0.005297
# 53        algorithm0          1.655483e+09        1.655483e+09       0.004952
# 56        algorithm7          1.655483e+09        1.655483e+09       0.006067
# 57        algorithm3          1.655483e+09        1.655483e+09       0.004752
# 58        algorithm2          1.655483e+09        1.655483e+09       0.006733
# 61        algorithm6          1.655483e+09        1.655483e+09       0.005435
# 67       algorithm20          1.655483e+09        1.655483e+09       0.005348
# 69       algorithm14          1.655483e+09        1.655483e+09       0.005821
# 76       algorithm10          1.655483e+09        1.655483e+09       0.009702
# 77       algorithm24          1.655483e+09        1.655483e+09       0.005954
# 80        algorithm9          1.655483e+09        1.655483e+09       0.005764
# 86       algorithm11          1.655483e+09        1.655483e+09       0.004889
# 87       algorithm25          1.655483e+09        1.655483e+09       0.006568
# 90        algorithm8          1.655483e+09        1.655483e+09       0.005770
# 96       algorithm21          1.655483e+09        1.655483e+09       0.005925
# 98       algorithm15          1.655483e+09        1.655483e+09       0.006407
# 20       algorithm33          1.655483e+09        1.655483e+09       0.004710
#
#      case:flops  case:num_kernels  case:rel-flops  case:rel-duration
# 4   344000000.0                 8             0.0           0.003625
# 8   344000000.0                 8             0.0           0.001486
# 14  344000000.0                 8             0.0           0.001213
# 17  344000000.0                 8             0.0           0.000535
# 23  344000000.0                 8             0.0           0.000492
# 26  344000000.0                 8             0.0           0.000947
# 31  344000000.0                 8             0.0           0.000612
# 37  344000000.0                 8             0.0           0.000020
# 39  344000000.0                 8             0.0           0.000613
# 44  344000000.0                 8             0.0           0.001012
# 49  344000000.0                 8             0.0           0.001011
# 51  344000000.0                 8             0.0           0.000587
# 53  344000000.0                 8             0.0           0.000242
# 56  344000000.0                 8             0.0           0.001357
# 57  344000000.0                 8             0.0           0.000042
# 58  344000000.0                 8             0.0           0.002023
# 61  344000000.0                 8             0.0           0.000725
# 67  344000000.0                 8             0.0           0.000638
# 69  344000000.0                 8             0.0           0.001111
# 76  344000000.0                 8             0.0           0.004992
# 77  344000000.0                 8             0.0           0.001244
# 80  344000000.0                 8             0.0           0.001054
# 86  344000000.0                 8             0.0           0.000179
# 87  344000000.0                 8             0.0           0.001858
# 90  344000000.0                 8             0.0           0.001060
# 96  344000000.0                 8             0.0           0.001215
# 98  344000000.0                 8             0.0           0.001697
# 20  345000000.0                 8       1000000.0           0.000000

# %%
run_competing.measure_competing_variants(reps=10)
run_competing.prepare_event_data()
measurements = run_competing.duration_competing
measurements.head()
# Out:
# Running Experiments
# Experiments completed
#   case:concept:name  case:timestamp:start  case:timestamp:end  case:duration
# 0     algorithm18_9          1.655483e+09        1.655483e+09       0.006068
# 1     algorithm33_4          1.655483e+09        1.655483e+09       0.006453
# 2     algorithm16_3          1.655483e+09        1.655483e+09       0.005783
# 3     algorithm22_7          1.655483e+09        1.655483e+09       0.005955
# 4      algorithm0_2          1.655483e+09        1.655483e+09       0.005921

# %%
ct
# Out:
#    case:concept:name  case:timestamp:start  case:timestamp:end  case:duration  \
# 4        algorithm12          1.655483e+09        1.655483e+09       0.008335
# 8        algorithm26          1.655483e+09        1.655483e+09       0.006196
# 14       algorithm22          1.655483e+09        1.655483e+09       0.005923
# 17       algorithm16          1.655483e+09        1.655483e+09       0.005245
# 23       algorithm23          1.655483e+09        1.655483e+09       0.005202
# 26       algorithm17          1.655483e+09        1.655483e+09       0.005657
# 31       algorithm13          1.655483e+09        1.655483e+09       0.005322
# 37       algorithm18          1.655483e+09        1.655483e+09       0.004730
# 39        algorithm1          1.655483e+09        1.655483e+09       0.005323
# 44        algorithm5          1.655483e+09        1.655483e+09       0.005722
# 49        algorithm4          1.655483e+09        1.655483e+09       0.005721
# 51       algorithm19          1.655483e+09        1.655483e+09       0.005297
# 53        algorithm0          1.655483e+09        1.655483e+09       0.004952
# 56        algorithm7          1.655483e+09        1.655483e+09       0.006067
# 57        algorithm3          1.655483e+09        1.655483e+09       0.004752
# 58        algorithm2          1.655483e+09        1.655483e+09       0.006733
# 61        algorithm6          1.655483e+09        1.655483e+09       0.005435
# 67       algorithm20          1.655483e+09        1.655483e+09       0.005348
# 69       algorithm14          1.655483e+09        1.655483e+09       0.005821
# 76       algorithm10          1.655483e+09        1.655483e+09       0.009702
# 77       algorithm24          1.655483e+09        1.655483e+09       0.005954
# 80        algorithm9          1.655483e+09        1.655483e+09       0.005764
# 86       algorithm11          1.655483e+09        1.655483e+09       0.004889
# 87       algorithm25          1.655483e+09        1.655483e+09       0.006568
# 90        algorithm8          1.655483e+09        1.655483e+09       0.005770
# 96       algorithm21          1.655483e+09        1.655483e+09       0.005925
# 98       algorithm15          1.655483e+09        1.655483e+09       0.006407
# 20       algorithm33          1.655483e+09        1.655483e+09       0.004710
#
#      case:flops  case:num_kernels  case:rel-flops  case:rel-duration
# 4   344000000.0                 8             0.0           0.003625
# 8   344000000.0                 8             0.0           0.001486
# 14  344000000.0                 8             0.0           0.001213
# 17  344000000.0                 8             0.0           0.000535
# 23  344000000.0                 8             0.0           0.000492
# 26  344000000.0                 8             0.0           0.000947
# 31  344000000.0                 8             0.0           0.000612
# 37  344000000.0                 8             0.0           0.000020
# 39  344000000.0                 8             0.0           0.000613
# 44  344000000.0                 8             0.0           0.001012
# 49  344000000.0                 8             0.0           0.001011
# 51  344000000.0                 8             0.0           0.000587
# 53  344000000.0                 8             0.0           0.000242
# 56  344000000.0                 8             0.0           0.001357
# 57  344000000.0                 8             0.0           0.000042
# 58  344000000.0                 8             0.0           0.002023
# 61  344000000.0                 8             0.0           0.000725
# 67  344000000.0                 8             0.0           0.000638
# 69  344000000.0                 8             0.0           0.001111
# 76  344000000.0                 8             0.0           0.004992
# 77  344000000.0                 8             0.0           0.001244
# 80  344000000.0                 8             0.0           0.001054
# 86  344000000.0                 8             0.0           0.000179
# 87  344000000.0                 8             0.0           0.001858
# 90  344000000.0                 8             0.0           0.001060
# 96  344000000.0                 8             0.0           0.001215
# 98  344000000.0                 8             0.0           0.001697
# 20  345000000.0                 8       1000000.0           0.000000

# %% [markdown]
# ## Initial Hypothesis: Sort algorithms by single-run execution time

# %%
alg_list = list(ct.sort_values(by=['case:duration'])['case:concept:name'])
alg_list
# Out:
# ['algorithm33',
#  'algorithm18',
#  'algorithm3',
#  'algorithm11',
#  'algorithm0',
#  'algorithm23',
#  'algorithm16',
#  'algorithm19',
#  'algorithm13',
#  'algorithm1',
#  'algorithm20',
#  'algorithm6',
#  'algorithm17',
#  'algorithm4',
#  'algorithm5',
#  'algorithm9',
#  'algorithm8',
#  'algorithm14',
#  'algorithm22',
#  'algorithm21',
#  'algorithm24',
#  'algorithm7',
#  'algorithm26',
#  'algorithm15',
#  'algorithm25',
#  'algorithm2',
#  'algorithm12',
#  'algorithm10']

# %%
rank_variants = RankVariants(measurements,alg_list)
ranks = rank_variants.sortAlgs(75,25)
all_ranks, mean_ranks = rank_variants.calculate_mean_rank()

# %%
pd.DataFrame(rank_variants.comparision_matrix)
# Out:
#              algorithm33  algorithm18  algorithm3  algorithm11  algorithm0  \
# algorithm33           -1            1          -1           -1          -1
# algorithm18            1           -1           1            1          -1
# algorithm3            -1            1          -1            0           0
# algorithm11           -1            1           2           -1           1
# algorithm0            -1           -1           2            1          -1
# algorithm23           -1           -1           1           -1          -1
# algorithm16           -1           -1          -1           -1          -1
# algorithm19           -1           -1          -1           -1          -1
# algorithm13           -1           -1          -1           -1          -1
# algorithm1            -1           -1          -1           -1          -1
# algorithm20           -1           -1          -1           -1          -1
# algorithm6            -1           -1          -1           -1          -1
# algorithm17           -1           -1          -1           -1          -1
# algorithm4            -1           -1          -1           -1          -1
# algorithm5            -1           -1          -1           -1          -1
# algorithm9            -1           -1          -1           -1          -1
# algorithm8            -1           -1          -1           -1          -1
# algorithm14           -1           -1          -1           -1          -1
# algorithm22           -1           -1          -1           -1          -1
# algorithm21           -1           -1          -1           -1          -1
# algorithm24           -1           -1          -1           -1          -1
# algorithm7            -1           -1          -1           -1          -1
# algorithm26           -1           -1          -1           -1          -1
# algorithm15           -1           -1          -1           -1          -1
# algorithm25           -1           -1          -1           -1          -1
# algorithm2            -1           -1          -1           -1          -1
# algorithm12           -1           -1          -1           -1          -1
# algorithm10           -1           -1          -1           -1          -1
#
#              algorithm23  algorithm16  algorithm19  algorithm13  algorithm1  \
# algorithm33           -1           -1           -1           -1          -1
# algorithm18           -1           -1           -1           -1          -1
# algorithm3             1           -1           -1           -1          -1
# algorithm11           -1           -1           -1           -1          -1
# algorithm0            -1           -1           -1           -1          -1
# algorithm23           -1            1           -1           -1          -1
# algorithm16            1           -1            1           -1          -1
# algorithm19           -1            1           -1            1          -1
# algorithm13           -1           -1            1           -1           1
# algorithm1            -1           -1           -1            1          -1
# algorithm20           -1           -1           -1           -1           1
# algorithm6            -1           -1           -1           -1          -1
# algorithm17           -1           -1           -1           -1          -1
# algorithm4            -1           -1           -1           -1          -1
# algorithm5            -1           -1           -1           -1          -1
# algorithm9            -1           -1           -1           -1          -1
# algorithm8            -1           -1           -1           -1          -1
# algorithm14           -1           -1           -1           -1          -1
# algorithm22           -1           -1           -1           -1          -1
# algorithm21           -1           -1           -1           -1          -1
# algorithm24           -1           -1           -1           -1          -1
# algorithm7            -1           -1           -1           -1          -1
# algorithm26           -1           -1           -1           -1          -1
# algorithm15           -1           -1           -1           -1          -1
# algorithm25           -1           -1           -1           -1          -1
# algorithm2            -1           -1           -1           -1          -1
# algorithm12           -1           -1           -1           -1          -1
# algorithm10           -1           -1           -1           -1          -1
#
#              ...  algorithm22  algorithm21  algorithm24  algorithm7  \
# algorithm33  ...           -1           -1           -1          -1
# algorithm18  ...           -1           -1           -1          -1
# algorithm3   ...           -1           -1           -1          -1
# algorithm11  ...           -1           -1           -1          -1
# algorithm0   ...           -1           -1           -1          -1
# algorithm23  ...           -1           -1           -1          -1
# algorithm16  ...           -1           -1           -1          -1
# algorithm19  ...           -1           -1           -1          -1
# algorithm13  ...           -1           -1           -1          -1
# algorithm1   ...           -1           -1           -1          -1
# algorithm20  ...           -1           -1           -1          -1
# algorithm6   ...           -1           -1           -1          -1
# algorithm17  ...           -1           -1           -1          -1
# algorithm4   ...           -1           -1           -1          -1
# algorithm5   ...           -1           -1           -1          -1
# algorithm9   ...           -1           -1           -1          -1
# algorithm8   ...           -1           -1           -1          -1
# algorithm14  ...            1           -1           -1          -1
# algorithm22  ...           -1            1           -1          -1
# algorithm21  ...            1           -1            1           1
# algorithm24  ...           -1            1           -1           0
# algorithm7   ...           -1            1            2          -1
# algorithm26  ...           -1           -1            1          -1
# algorithm15  ...           -1           -1           -1          -1
# algorithm25  ...           -1           -1           -1          -1
# algorithm2   ...           -1           -1           -1          -1
# algorithm12  ...           -1           -1           -1          -1
# algorithm10  ...           -1           -1           -1          -1
#
#              algorithm26  algorithm15  algorithm25  algorithm2  algorithm12  \
# algorithm33           -1           -1           -1          -1           -1
# algorithm18           -1           -1           -1          -1           -1
# algorithm3            -1           -1           -1          -1           -1
# algorithm11           -1           -1           -1          -1           -1
# algorithm0            -1           -1           -1          -1           -1
# algorithm23           -1           -1           -1          -1           -1
# algorithm16           -1           -1           -1          -1           -1
# algorithm19           -1           -1           -1          -1           -1
# algorithm13           -1           -1           -1          -1           -1
# algorithm1            -1           -1           -1          -1           -1
# algorithm20           -1           -1           -1          -1           -1
# algorithm6            -1           -1           -1          -1           -1
# algorithm17           -1           -1           -1          -1           -1
# algorithm4            -1           -1           -1          -1           -1
# algorithm5            -1           -1           -1          -1           -1
# algorithm9            -1           -1           -1          -1           -1
# algorithm8            -1           -1           -1          -1           -1
# algorithm14           -1           -1           -1          -1           -1
# algorithm22           -1           -1           -1          -1           -1
# algorithm21           -1           -1           -1          -1           -1
# algorithm24            1           -1           -1          -1           -1
# algorithm7            -1           -1           -1          -1           -1
# algorithm26           -1            1           -1          -1           -1
# algorithm15            1           -1            1          -1           -1
# algorithm25           -1            1           -1           1           -1
# algorithm2            -1           -1            1          -1            1
# algorithm12           -1           -1           -1           1           -1
# algorithm10           -1           -1           -1          -1            1
#
#              algorithm10
# algorithm33           -1
# algorithm18           -1
# algorithm3            -1
# algorithm11           -1
# algorithm0            -1
# algorithm23           -1
# algorithm16           -1
# algorithm19           -1
# algorithm13           -1
# algorithm1            -1
# algorithm20           -1
# algorithm6            -1
# algorithm17           -1
# algorithm4            -1
# algorithm5            -1
# algorithm9            -1
# algorithm8            -1
# algorithm14           -1
# algorithm22           -1
# algorithm21           -1
# algorithm24           -1
# algorithm7            -1
# algorithm26           -1
# algorithm15           -1
# algorithm25           -1
# algorithm2            -1
# algorithm12            1
# algorithm10           -1
#
# [28 rows x 28 columns]

# %%
ranks
# Out:
#    case:concept:name  case:rank
# 0        algorithm33          0
# 1        algorithm18          0
# 2         algorithm3          0
# 3        algorithm11          0
# 4         algorithm0          0
# 5        algorithm23          0
# 6        algorithm16          0
# 7        algorithm19          0
# 8        algorithm13          0
# 9         algorithm1          0
# 10       algorithm20          0
# 11        algorithm6          0
# 12       algorithm17          0
# 13        algorithm4          0
# 14        algorithm5          0
# 15        algorithm9          0
# 16        algorithm8          0
# 17       algorithm14          0
# 18       algorithm22          0
# 19       algorithm21          0
# 20       algorithm24          0
# 21        algorithm7          0
# 22       algorithm26          1
# 23       algorithm15          1
# 24       algorithm25          1
# 25        algorithm2          1
# 26       algorithm12          1
# 27       algorithm10          1

# %%
all_ranks
# Out:
#                    case:rank  case:rank  case:rank  case:rank  case:rank  \
# case:concept:name
# algorithm33                0          0          0          0          0
# algorithm18                0          0          0          0          0
# algorithm3                 0          0          0          0          0
# algorithm11                0          0          0          0          0
# algorithm0                 0          0          0          0          0
# algorithm23                0          0          0          0          0
# algorithm16                0          0          0          0          0
# algorithm19                0          0          0          0          0
# algorithm13                0          0          0          0          0
# algorithm1                 0          0          0          0          0
# algorithm20                0          0          0          0          0
# algorithm6                 0          0          0          0          0
# algorithm17                0          0          0          0          0
# algorithm4                 0          0          0          0          0
# algorithm5                 0          0          0          0          0
# algorithm9                 0          0          0          0          0
# algorithm8                 0          0          0          0          0
# algorithm14                0          0          0          0          0
# algorithm22                0          0          0          0          0
# algorithm21                0          0          0          0          0
# algorithm24                0          0          0          0          0
# algorithm7                 0          0          0          0          0
# algorithm26                0          0          0          0          1
# algorithm15                0          0          0          0          1
# algorithm25                0          0          0          0          1
# algorithm2                 0          0          0          0          1
# algorithm12                0          0          0          0          1
# algorithm10                0          0          0          0          1
#
#                    case:rank  case:rank
# case:concept:name
# algorithm33                0          0
# algorithm18                0          0
# algorithm3                 0          0
# algorithm11                0          0
# algorithm0                 0          0
# algorithm23                0          0
# algorithm16                0          0
# algorithm19                0          0
# algorithm13                0          0
# algorithm1                 0          0
# algorithm20                0          0
# algorithm6                 0          0
# algorithm17                0          0
# algorithm4                 0          0
# algorithm5                 0          0
# algorithm9                 0          0
# algorithm8                 0          0
# algorithm14                1          1
# algorithm22                1          1
# algorithm21                1          1
# algorithm24                1          2
# algorithm7                 1          1
# algorithm26                2          2
# algorithm15                2          2
# algorithm25                2          2
# algorithm2                 2          2
# algorithm12                2          2
# algorithm10                2          2

# %%
mean_ranks
# Out:
#    case:concept:name  case:mean-rank
# 0        algorithm33        0.000000
# 16        algorithm8        0.000000
# 15        algorithm9        0.000000
# 14        algorithm5        0.000000
# 12       algorithm17        0.000000
# 11        algorithm6        0.000000
# 10       algorithm20        0.000000
# 9         algorithm1        0.000000
# 13        algorithm4        0.000000
# 7        algorithm19        0.000000
# 6        algorithm16        0.000000
# 5        algorithm23        0.000000
# 4         algorithm0        0.000000
# 3        algorithm11        0.000000
# 2         algorithm3        0.000000
# 1        algorithm18        0.000000
# 8        algorithm13        0.000000
# 21        algorithm7        0.285714
# 19       algorithm21        0.285714
# 18       algorithm22        0.285714
# 17       algorithm14        0.285714
# 20       algorithm24        0.428571
# 26       algorithm12        0.714286
# 22       algorithm26        0.714286
# 23       algorithm15        0.714286
# 24       algorithm25        0.714286
# 25        algorithm2        0.714286
# 27       algorithm10        0.714286

# %%
rank_variants.show_measurements_boxplots(outliers=False)

# %% [markdown]
# ## Insights

# %%
et = run_competing.event_table_competing
et
# Out:
#      case:concept:name                     concept:name  concept:flops  \
# 0        algorithm18_9            LAPACK.potrf_3.33e+08    333000000.0
# 1        algorithm18_9                       trsm_1e+07     10000000.0
# 2        algorithm18_9                       syrk_1e+05       100000.0
# 3        algorithm18_9  ml4, ml3 = LAPACK.syev_3.43e+03         3430.0
# 4        algorithm18_9                       trsv_1e+06      1000000.0
# ...                ...                              ...            ...
# 2235      algorithm6_4                       trsv_1e+06      1000000.0
# 2236      algorithm6_4                       gemv_2e+04        20000.0
# 2237      algorithm6_4                 LAPACK.potrf_333          333.0
# 2238      algorithm6_4                         trsv_100          100.0
# 2239      algorithm6_4                         trsv_100          100.0
#
#             concept:operation                            concept:kernel  \
# 0               (L2 L2^T) = M                   LAPACK.potrf!('L', ml1)
# 1           tmp12 = (L2^-1 X)  trsm!('L', 'L', 'N', 'N', 1.0, ml1, ml0)
# 2     tmp14 = (tmp12^T tmp12)       syrk!('L', 'T', 1.0, ml0, 0.0, ml3)
# 3     (Z18 W19 Z18^T) = tmp14    ml4, ml3 = LAPACK.syev!('V', 'L', ml3)
# 4           tmp68 = (L2^-1 y)            trsv!('L', 'N', 'N', ml1, ml2)
# ...                       ...                                       ...
# 2235        tmp68 = (L2^-1 y)            trsv!('L', 'N', 'N', ml1, ml2)
# 2236  tmp21 = (tmp12^T tmp68)       gemv!('T', 1.0, ml0, ml2, 0.0, ml4)
# 2237      (L15 L15^T) = tmp14                   LAPACK.potrf!('L', ml3)
# 2238   tmp23 = (L15^-1 tmp21)            trsv!('L', 'N', 'N', ml3, ml4)
# 2239   tmp24 = (L15^-T tmp23)            trsv!('L', 'T', 'N', ml3, ml4)
#
#       timestamp:start  timestamp:end
# 0        1.655483e+09   1.655483e+09
# 1        1.655483e+09   1.655483e+09
# 2        1.655483e+09   1.655483e+09
# 3        1.655483e+09   1.655483e+09
# 4        1.655483e+09   1.655483e+09
# ...               ...            ...
# 2235     1.655483e+09   1.655483e+09
# 2236     1.655483e+09   1.655483e+09
# 2237     1.655483e+09   1.655483e+09
# 2238     1.655483e+09   1.655483e+09
# 2239     1.655483e+09   1.655483e+09
#
# [2240 rows x 7 columns]

# %%
pn = DiscoverPN(et)
for trace in pn.event_log:
    alg = trace.attributes['concept:name'].split('_')[0]
    alg_rank = ranks[ranks['case:concept:name'] == alg]['case:rank'].values[0]
    alg_mean_rank = mean_ranks[mean_ranks['case:concept:name'] == alg]['case:mean-rank'].values[0]
    trace.attributes['case:algorithm'] = alg
    trace.attributes['case:rank'] = alg_rank
    trace.attributes['case:mean-rank'] = alg_mean_rank

# %%
#for trace in pn.event_log:
#    print(trace.attributes)

# %%
def filtered_log_by_rank(log,rank):
    filtered_log = pm4py.filter_log(lambda x: x.attributes['case:rank'] == rank, log)
    return filtered_log

def filtered_log_by_alg_list(log,alg_list):
    filtered_log = pm4py.filter_log(lambda x: x.attributes['case:algorithm'] in alg_list, log)
    return filtered_log

# %% [markdown]
# ### Algorithm 1

# %%
filtered_log_by_alg = filtered_log_by_alg_list(pn.event_log, ['algorithm1'])

# for trace in filtered_log_by_alg:
#     print(trace.attributes)

net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log_by_alg)
pn.visualize_pn(net, im, fm)

# %% [markdown]
# ### Algorithm 0

# %%
filtered_log_by_alg = filtered_log_by_alg_list(pn.event_log, ['algorithm0'])
net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log_by_alg)
pn.visualize_pn(net, im, fm)

# %% [markdown]
# ## Work flow: Rank 0 algorithms

# %% [markdown]
# ### Knernels Used

# %%
filtered_log=filtered_log_by_rank(pn.event_log,0)
net, im, fm = pn.inductive_miner(filtered_log=filtered_log)
pn.visualize_pn(net, im, fm)

# %%
net, im, fm = pn.inductive_miner(activity='concept:operation',filtered_log=filtered_log)
pn.visualize_pn(net, im, fm)
